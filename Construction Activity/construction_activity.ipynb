# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 kB 24.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="/content/drive/MyDrive/SiteVision Part 1/data.yaml" epochs=50 imgsz=640 batch=16
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 93.5MB/s]
# Ultralytics 8.3.34 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model="/content/runs/detect/train/weights/best.pt" data="/content/drive/MyDrive/SiteVision Part 1/data.yaml"
# Out:
# Ultralytics 8.3.34 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,007,403 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/SiteVision Part 1/dataset/val/labels.cache... 66 images, 0 backgrounds, 0 corrupt: 100% 66/66 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:02<00:00,  2.29it/s]
#                    all         66        126      0.947      0.929      0.963      0.787
#                  Paver          7         10      0.972          1      0.995      0.853
#              Compactor          6         14      0.992          1      0.995      0.902
#              Bulldozer         21         24          1      0.949      0.995      0.865
#              Excavator         21         30       0.85      0.867      0.923      0.572
#       Concrete Mixture          2          4      0.919          1      0.995      0.945
# ...

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train/weights/best.pt" conf=0.30 source="/content/drive/MyDrive/SiteVision Part 1/dataset/val/images"
# Out:
# Ultralytics 8.3.34 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,007,403 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/66 /content/drive/MyDrive/SiteVision Part 1/dataset/val/images/0LrYNXTR.jpeg: 384x640 1 Paver, 4 Compactors, 35.6ms
# image 2/66 /content/drive/MyDrive/SiteVision Part 1/dataset/val/images/0YfZWgaR.jpeg: 384x640 1 Excavator, 7.2ms
# image 3/66 /content/drive/MyDrive/SiteVision Part 1/dataset/val/images/0b0G5Iy9.jpeg: 384x640 1 Bulldozer, 6.1ms
# image 4/66 /content/drive/MyDrive/SiteVision Part 1/dataset/val/images/0fXwmEBG.jpeg: 384x640 1 Bulldozer, 6.4ms
# image 5/66 /content/drive/MyDrive/SiteVision Part 1/dataset/val/images/1BCrl64k.jpeg: 384x640 2 Concrete Mixtures, 3 Crane's, 6.0ms
# image 6/66 /content/drive/MyDrive/SiteVision Part 1/dataset/val/images/1EIgRdGD.jpeg: 480x640 1 Paver, 2 Compactors, 32.8ms
# ...
